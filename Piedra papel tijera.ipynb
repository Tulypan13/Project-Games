# %%
import random

opciones = ["piedra", "papel", "tijera", "lagarto", "spock"]

def determinar_ganador(opcion_usuario, opcion_programa):
    if opcion_usuario == opcion_programa:
        return "Empate"
    elif (opcion_usuario == "piedra" and (opcion_programa == "tijera" or opcion_programa == "lagarto")) or \
         (opcion_usuario == "papel" and (opcion_programa == "piedra" or opcion_programa == "spock")) or \
         (opcion_usuario == "tijera" and (opcion_programa == "papel" or opcion_programa == "lagarto")) or \
         (opcion_usuario == "lagarto" and (opcion_programa == "papel" or opcion_programa == "spock")) or \
         (opcion_usuario == "spock" and (opcion_programa == "piedra" or opcion_programa == "tijera")):
        return "Ganaste"
    else:
        return "Perdiste"

while True:
    opcion_usuario = input("Ingresa tu opción (piedra, papel, tijera, lagarto o spock): ")
    opcion_programa = random.choice(opciones)
    
    print(f"Tú elegiste {opcion_usuario}, el programa eligió {opcion_programa}")
    print(determinar_ganador(opcion_usuario, opcion_programa))
    
    jugar_nuevamente = input("¿Quieres jugar de nuevo? (s/n): ")
    if jugar_nuevamente.lower() != "s":
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13332\1908141039.py in <module>
#      16
#      17 while True:
# ---> 18     opcion_usuario = input("Ingresa tu opción (piedra, papel, tijera, lagarto o spock): ")
#      19     opcion_programa = random.choice(opciones)
#      20
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %% [markdown]
# Explicación del código:
#
# Primero, importamos el módulo random para generar una opción aleatoria para el programa.
#
# Creamos una lista con todas las opciones posibles: "piedra", "papel", "tijera", "lagarto" y "spock".
#
# Definimos una función llamada determinar_ganador que toma dos argumentos: la opción del usuario y la opción del programa. La función devuelve "Empate" si las opciones son iguales, "Ganaste" si el usuario ganó y "Perdiste" si el usuario perdió.
#
# Luego, entramos en un bucle infinito que permite al usuario jugar varias veces. En cada iteración, pedimos al usuario que ingrese su opción y generamos una opción aleatoria para el programa.
#
# Imprimimos ambas opciones y llamamos a la función determinar_ganador para saber quién ganó.
#
# Finalmente, preguntamos al usuario si desea jugar de nuevo. Si la respuesta no es "s", salimos del bucle y el programa termina.

# %%
import random

reglas = {
    "piedra": ["tijera", "lagarto"],
    "papel": ["piedra", "spock"],
    "tijera": ["papel", "lagarto"],
    "lagarto": ["papel", "spock"],
    "spock": ["piedra", "tijera"]
}

opciones = list(reglas.keys())

def determinar_ganador1(opcion_usuario, opcion_programa):
    
    
    if opcion_usuario == opcion_programa:
        return "Empate"
    elif opcion_programa in reglas[opcion_usuario]:
        return "Ganaste"
    else:
        return "Perdiste"

while True:
    opcion_usuario = input("Ingresa tu opción (piedra, papel, tijera, lagarto o spock): ")
    opcion_programa = random.choice(opciones)
    
    print(f"Tú elegiste {opcion_usuario}, el programa eligió {opcion_programa}")
    print(determinar_ganador1(opcion_usuario, opcion_programa))
    
    jugar_nuevamente = input("¿Quieres jugar de nuevo? (s/n): ")
    if jugar_nuevamente.lower() != "s":
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13332\3111519173.py in <module>
#      22
#      23 while True:
# ---> 24     opcion_usuario = input("Ingresa tu opción (piedra, papel, tijera, lagarto o spock): ")
#      25     opcion_programa = random.choice(opciones)
#      26
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %% [markdown]
# Una forma de reducir el uso de if es utilizando un diccionario para definir las reglas del juego. En este caso, las claves del diccionario serán las opciones y los valores serán las opciones que vencen a la clave.

# %% [markdown]
# Con este diccionario, podemos determinar si una opción vence a otra simplemente revisando si la opción se encuentra en la lista de opciones vencidas de la otra opción.
#
# Además, podemos utilizar el método random.choice de la misma forma que antes para generar una opción aleatoria para el programa.

# %%
import random

def determinar_ganador2(opcion_usuario: str, opcion_programa: str) -> str:
    """
    Determina el ganador del juego de piedra, papel, tijera, lagarto, spock.

    Args:
        opcion_usuario (str): La opción elegida por el usuario.
        opcion_programa (str): La opción elegida por el programa.

    Returns:
        str: El resultado del juego: "Ganaste", "Perdiste" o "Empate".
    """
    reglas = {
        "piedra": ["tijera", "lagarto"],
        "papel": ["piedra", "spock"],
        "tijera": ["papel", "lagarto"],
        "lagarto": ["papel", "spock"],
        "spock": ["piedra", "tijera"]
    }
    if opcion_usuario == opcion_programa:
        return "Empate"
    elif opcion_programa in reglas[opcion_usuario]:
        return "Ganaste"
    else:
        return "Perdiste"

def jugar2() -> None:
    """
    Función principal del juego de piedra, papel, tijera, lagarto, spock.
    Permite al usuario jugar varias rondas contra el programa.
    """
    opciones = ["piedra", "papel", "tijera", "lagarto", "spock"]
    while True:
        opcion_usuario = input("Ingresa tu opción (piedra, papel, tijera, lagarto o spock): ")
        opcion_programa = random.choice(opciones)
        
        print(f"Tú elegiste {opcion_usuario}, el programa eligió {opcion_programa}")
        print(determinar_ganador(opcion_usuario, opcion_programa))
        
        jugar_nuevamente = input("¿Quieres jugar de nuevo? (s/n): ")
        if jugar_nuevamente.lower() != "s":
            break

# %%
jugar2()
# Out:
# Ingresa tu opción (piedra, papel, tijera, lagarto o spock): papel
# Tú elegiste papel, el programa eligió papel
# Empate
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13332\2849728921.py in <module>
# ----> 1 jugar2()
#
# ~\AppData\Local\Temp\ipykernel_13332\3970371026.py in jugar2()
#      39         print(determinar_ganador(opcion_usuario, opcion_programa))
#      40
# ---> 41         jugar_nuevamente = input("¿Quieres jugar de nuevo? (s/n): ")
#      42         if jugar_nuevamente.lower() != "s":
#      43             break
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
# ...

# %%
import random

def determinar_ganador3(opcion_usuario: str, opcion_programa: str) -> str:
    """
    Determina el ganador de una ronda del juego de piedra, papel, tijera, lagarto, spock.

    Args:
        opcion_usuario (str): La opción elegida por el usuario.
        opcion_programa (str): La opción elegida por el programa.

    Returns:
        str: El ganador de la ronda: "usuario", "programa" o "empate".
    """
    reglas = {
        "piedra": ["tijera", "lagarto"],
        "papel": ["piedra", "spock"],
        "tijera": ["papel", "lagarto"],
        "lagarto": ["papel", "spock"],
        "spock": ["piedra", "tijera"]
    }
    if opcion_usuario == opcion_programa:
        return "empate"
    elif opcion_programa in reglas[opcion_usuario]:
        return "usuario"
    else:
        return "programa"

def jugar3() -> None:
    """
    Función principal del juego de piedra, papel, tijera, lagarto, spock.
    Permite al usuario jugar varias rondas contra el programa.
    """
    opciones = ["piedra", "papel", "tijera", "lagarto", "spock"]
    victorias_usuario = 0
    victorias_programa = 0
    while True:
        opcion_usuario = input("Ingresa tu opción (piedra, papel, tijera, lagarto o spock): ")
        opcion_programa = random.choice(opciones)
        
        print(f"Tú elegiste {opcion_usuario}, el programa eligió {opcion_programa}")
        ganador_ronda = determinar_ganador(opcion_usuario, opcion_programa)
        if ganador_ronda == "empate":
            print("Empate")
        elif ganador_ronda == "usuario":
            print("Ganaste")
            victorias_usuario += 1
        else:
            print("Perdiste")
            victorias_programa += 1
        
        print(f"Victorias del usuario: {victorias_usuario}")
        print(f"Victorias del programa: {victorias_programa}")
        
        jugar_nuevamente = input("¿Quieres jugar de nuevo? (s/n): ")
        if jugar_nuevamente.lower() != "s":
            break

# %% [markdown]
#  podrías modificar la función determinar_ganador para que devuelva el ganador de la ronda, en lugar del resultado del juego. Luego, podrías agregar variables para llevar la cuenta de las victorias del usuario y del programa en la función jugar.

# %%
jugar3()
# Out:
# Ingresa tu opción (piedra, papel, tijera, lagarto o spock): papel
# Tú elegiste papel, el programa eligió papel
# Perdiste
# Victorias del usuario: 0
# Victorias del programa: 1
# ¿Quieres jugar de nuevo? (s/n): n

# %% [markdown]
# En este ejemplo, la función determinar_ganador ahora devuelve el ganador de la ronda ("usuario", "programa" o "empate"). La función jugar inicializa las variables victorias_usuario y victorias_programa en cero, y las actualiza después de cada ronda según el ganador de la ronda devuelto por determinar_ganador. La función también muestra las victorias del usuario y del programa después de cada ronda.

# %% [markdown]
# Para asegurarnos de que el usuario solo ingrese opciones válidas, podemos modificar la función jugar para incluir una verificación adicional después de que el usuario ingrese su opción. Si la opción del usuario no está en la lista de opciones válidas, la función le pedirá que ingrese una opción válida y volverá a solicitar la entrada del usuario.

# %%
import random

def determinar_ganador(opcion_usuario: str, opcion_programa: str) -> str:
    """
    Determina el ganador de una ronda del juego de piedra, papel, tijera, lagarto, spock.

    Args:
        opcion_usuario (str): La opción elegida por el usuario.
        opcion_programa (str): La opción elegida por el programa.

    Returns:
        str: El ganador de la ronda: "usuario", "programa" o "empate".
    """
    reglas = {
        "piedra": ["tijera", "lagarto"],
        "papel": ["piedra", "spock"],
        "tijera": ["papel", "lagarto"],
        "lagarto": ["papel", "spock"],
        "spock": ["piedra", "tijera"]
    }
    if opcion_usuario == opcion_programa:
        return "empate"
    elif opcion_programa in reglas[opcion_usuario]:
        return "usuario"
    else:
        return "programa"

def jugar() -> None:
    """
    Función principal del juego de piedra, papel, tijera, lagarto, spock.
    Permite al usuario jugar varias rondas contra el programa.
    """
    opciones = ["piedra", "papel", "tijera", "lagarto", "spock"]
    victorias_usuario = 0
    victorias_programa = 0
    while True:
        opcion_usuario = input("Ingresa tu opción (piedra, papel, tijera, lagarto o spock): ")
        while opcion_usuario not in opciones:
            opcion_usuario = input("Opción inválida. Ingresa tu opción (piedra, papel, tijera, lagarto o spock): ")
        
        opcion_programa = random.choice(opciones)
        
        print(f"Tú elegiste {opcion_usuario}, el programa eligió {opcion_programa}")
        ganador_ronda = determinar_ganador(opcion_usuario, opcion_programa)
        if ganador_ronda == "empate":
            print("Empate")
        elif ganador_ronda == "usuario":
            print("Ganaste")
            victorias_usuario += 1
        else:
            print("Perdiste")
            victorias_programa += 1
        
        print(f"Victorias del usuario: {victorias_usuario}")
        print(f"Victorias del programa: {victorias_programa}")
        
        jugar_nuevamente = input("¿Quieres jugar de nuevo? (s/n): ")
        if jugar_nuevamente.lower() != "s":
            print("¡Gracias por jugar!")
            break

# %%
jugar4()
# Out:
# Ingresa tu opción (piedra, papel, tijera, lagarto o spock): caca
# Opción inválida. Ingresa tu opción (piedra, papel, tijera, lagarto o spock): Piedra
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13332\382515390.py in <module>
# ----> 1 jugar4()
#
# ~\AppData\Local\Temp\ipykernel_13332\359931437.py in jugar4()
#      37         opcion_usuario = input("Ingresa tu opción (piedra, papel, tijera, lagarto o spock): ")
#      38         while opcion_usuario not in opciones:
# ---> 39             opcion_usuario = input("Opción inválida. Ingresa tu opción (piedra, papel, tijera, lagarto o spock): ")
#      40
#      41         opcion_programa = random.choice(opciones)
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
# ...

# %% [markdown]
# para hacer que las mayúsculas o minúsculas sean permitidas indistintamente, podemos convertir la entrada del usuario a minúsculas (o mayúsculas) antes de compararla con las opciones válidas.

# %%
import random

def determinar_ganador5(opcion_usuario: str, opcion_programa: str) -> str:
    """
    Determina el ganador de una ronda del juego de piedra, papel, tijera, lagarto, spock.

    Args:
        opcion_usuario (str): La opción elegida por el usuario.
        opcion_programa (str): La opción elegida por el programa.

    Returns:
        str: El ganador de la ronda: "usuario", "programa" o "empate".
    """
    reglas = {
        "piedra": ["tijera", "lagarto"],
        "papel": ["piedra", "spock"],
        "tijera": ["papel", "lagarto"],
        "lagarto": ["papel", "spock"],
        "spock": ["piedra", "tijera"]
    }
    if opcion_usuario == opcion_programa:
        return "empate"
    elif opcion_programa in reglas[opcion_usuario]:
        return "usuario"
    else:
        return "programa"

def jugar5() -> None:
    """
    Función principal del juego de piedra, papel, tijera, lagarto, spock.
    Permite al usuario jugar varias rondas contra el programa.
    """
    opciones = ["piedra", "papel", "tijera", "lagarto", "spock"]
    victorias_usuario = 0
    victorias_programa = 0
    nombre_usuario = input("Ingresa tu nombre de jugador: ")
    while True:
        opcion_usuario = input("Ingresa tu opción (piedra, papel, tijera, lagarto o spock): ").lower()
        while opcion_usuario not in opciones:
            opcion_usuario = input("Opción inválida. Ingresa tu opción (piedra, papel, tijera, lagarto o spock): ").lower()
        
        opcion_programa = random.choice(opciones)
        
        print(f"Tú elegiste {opcion_usuario}, el programa eligió {opcion_programa}")
        ganador_ronda = determinar_ganador5(opcion_usuario, opcion_programa)
        if ganador_ronda == "empate":
            print("Empate")
        elif ganador_ronda == "usuario":
            print("Ganaste")
            victorias_usuario += 1
        else:
            print("Perdiste")
            victorias_programa += 1
        
        print(f"Victorias del usuario: {victorias_usuario}")
        print(f"Victorias del programa: {victorias_programa}")
        
        jugar_nuevamente = input("¿Quieres jugar de nuevo? (si/no): ")
        if jugar_nuevamente.lower() != "si":
            print("¡Gracias por jugar!")
            break

# %%
jugar5()
# Out:
# Ingresa tu nombre: Carlitos
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18848\3570321354.py in <module>
# ----> 1 jugar5()
#       2
#
# ~\AppData\Local\Temp\ipykernel_18848\3717475644.py in jugar5()
#      36     nombre_usuario = input("Ingresa tu nombre: ")
#      37     while True:
# ---> 38         opcion_usuario = input("Ingresa tu opción (piedra, papel, tijera, lagarto o spock): ").lower()
#      39         while opcion_usuario not in opciones:
#      40             opcion_usuario = input("Opción inválida. Ingresa tu opción (piedra, papel, tijera, lagarto o spock): ").lower()
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
# ...

# %% [markdown]
# solo para piedra papel tijera

# %%
import random

def determinar_ganador(opcion_usuario: str, opcion_programa: str) -> str:
    """
    Determina el ganador de una ronda del juego de piedra, papel o tijera.

    Args:
        opcion_usuario (str): La opción elegida por el usuario.
        opcion_programa (str): La opción elegida por el programa.

    Returns:
        str: El ganador de la ronda: "usuario", "programa" o "empate".
    """
    reglas = {
        "piedra": ["tijera"],
        "papel": ["piedra"],
        "tijera": ["papel"]
    }
    if opcion_usuario == opcion_programa:
        return "empate"
    elif opcion_programa in reglas[opcion_usuario]:
        return "usuario"
    else:
        return "programa"

def jugar() -> None:
    """
    Función principal del juego de piedra, papel o tijera.
    Permite al usuario jugar varias rondas contra el programa.
    """
    opciones = ["piedra", "papel", "tijera"]
    victorias_usuario = 0
    victorias_programa = 0
    nombre_usuario = input("Ingresa tu nombre: ")
    while True:
        opcion_usuario = input("Ingresa tu opción (piedra, papel o tijera): ").lower()
        while opcion_usuario not in opciones:
            opcion_usuario = input("Opción inválida. Ingresa tu opción (piedra, papel o tijera): ").lower()
        
        opcion_programa = random.choice(opciones)
        
        print(f"{nombre_usuario}, elegiste {opcion_usuario}, el programa eligió {opcion_programa}")
        ganador_ronda = determinar_ganador(opcion_usuario, opcion_programa)
        if ganador_ronda == "empate":
            print("Empate")
        elif ganador_ronda == "usuario":
            print("Ganaste")
            victorias_usuario += 1
        else:
            print("Perdiste")
            victorias_programa += 1
        
        print(f"Victorias de {nombre_usuario}: {victorias_usuario}")
        print(f"Victorias del programa: {victorias_programa}")
        
        jugar_nuevamente = input("¿Quieres jugar de nuevo? (s/n): ")
        if jugar_nuevamente.lower() != "s":
            print("¡Gracias por jugar!")
            break

# %%
import random

def determinar_ganador1(opcion_usuario: str, opcion_programa: str) -> str:
    """
    Determina el ganador de una ronda del juego de piedra, papel o tijera.

    Args:
        opcion_usuario (str): La opción elegida por el usuario.
        opcion_programa (str): La opción elegida por el programa.

    Returns:
        str: El ganador de la ronda: "usuario", "programa" o "empate".
    """
    reglas = {
        "piedra": ["tijera"],
        "papel": ["piedra"],
        "tijera": ["papel"]
    }
    if opcion_usuario == opcion_programa:
        return "empate"
    elif opcion_programa in reglas[opcion_usuario]:
        return "usuario"
    else:
        return "programa"

def juego1() -> None:
    """
    Función principal del juego de piedra, papel o tijera.
    Permite al usuario jugar varias rondas contra el programa.
    """
    opciones = ["piedra", "papel", "tijera"]
    victorias_usuario = 0
    victorias_programa = 0
    nombre_usuario = input("Ingresa tu nombre: ")
    while True:
        opcion_usuario = input("Ingresa tu opción (piedra, papel o tijera): ").lower()
        while opcion_usuario not in opciones:
            opcion_usuario = input("Opción inválida. Ingresa tu opción (piedra, papel o tijera): ").lower()
        
        opcion_programa = random.choice(opciones)
        
        print(f"{nombre_usuario}, elegiste {opcion_usuario}, el programa eligió {opcion_programa}")
        ganador_ronda = determinar_ganador1(opcion_usuario, opcion_programa)
        if ganador_ronda == "empate":
            print("\n\t Empate\n")
        elif ganador_ronda == "usuario":
            print("\n\t Ganaste\n")
            victorias_usuario += 1
        else:
            print("\n\t Perdiste\n")
            victorias_programa += 1
        
        print(f"Victorias de {nombre_usuario}: {victorias_usuario}")
        print(f"Victorias del programa: {victorias_programa}")
        
        jugar_nuevamente = input("¿Quieres jugar de nuevo? (s/n): ")
        if jugar_nuevamente.lower() != "s":
            print("¡Gracias por jugar!")
            break


def determinar_ganador2(opcion_usuario: str, opcion_programa: str) -> str:
    """
    Determina el ganador de una ronda del juego de piedra, papel, tijera, lagarto, spock.

    Args:
        opcion_usuario (str): La opción elegida por el usuario.
        opcion_programa (str): La opción elegida por el programa.

    Returns:
        str: El ganador de la ronda: "usuario", "programa" o "empate".
    """
    reglas = {
        "piedra": ["tijera", "lagarto"],
        "papel": ["piedra", "spock"],
        "tijera": ["papel", "lagarto"],
        "lagarto": ["papel", "spock"],
        "spock": ["piedra", "tijera"]
    }
    if opcion_usuario == opcion_programa:
        return "empate"
    elif opcion_programa in reglas[opcion_usuario]:
        return "usuario"
    else:
        return "programa"

def juego2() -> None:
    """
    Función principal del juego de piedra, papel, tijera, lagarto, spock.
    Permite al usuario jugar varias rondas contra el programa.
    """
    opciones = ["piedra", "papel", "tijera", "lagarto", "spock"]
    victorias_usuario = 0
    victorias_programa = 0
    nombre_usuario = input("Ingresa tu nombre: ")
    
    while True:
        opcion_usuario = input("Ingresa tu opción (piedra, papel, tijera, lagarto o spock): ").lower()
        while opcion_usuario not in opciones:
            opcion_usuario = input("Opción inválida. Ingresa tu opción (piedra, papel, tijera, lagarto o spock): ").lower()
        
        opcion_programa = random.choice(opciones)
        
        print(f"Tú elegiste {opcion_usuario}, el programa eligió {opcion_programa}")
        ganador_ronda = determinar_ganador2(opcion_usuario, opcion_programa)
        if ganador_ronda == "empate":
            print("\n\t Empate\n")
        elif ganador_ronda == "usuario":
            print("\n\t Ganaste\n")
            victorias_usuario += 1
        else:
            print("\n\t Perdiste\n")
            victorias_programa += 1
        
        print(f"Victorias de {nombre_usuario}: {victorias_usuario}")
        print(f"Victorias del programa: {victorias_programa}")
        
        jugar_nuevamente = input("¿Quieres jugar de nuevo? (s/n): ")
        if jugar_nuevamente.lower() != "s":
            print("¡Gracias por jugar!")
            break  

def juego3():
    while True: 
        secret_number = random.randint(1, 10)
        guess = None
        num_tries = 0
    
        while guess != secret_number:
            guess = int(input("Guess a number from 1 to 10: "))
            num_tries += 1
         
            if guess < secret_number:
                print("\n\t FAIL\n")
                print("Too low, try again!")
              
            elif guess > secret_number:
                print("\n\t FAIL\n")
                print("Too high, try again!")
           
            else:
                print(f"Congratulations! {guess} is correct!")
                print(f"You took {num_tries} tries.")
        
        jugar_nuevamente = input("¿Quieres jugar de nuevo? (s/n): ")
        if jugar_nuevamente.lower() != "s":
            break  
                
    print("¡Gracias por jugar!")  
            
        
def Jugar():
    """
    Función principal del proyecto.
    Permite al usuario jugar i seleccionar  el juego a jugar contra el programa.
    """
    print("¡Bienvenido a la sala de juegos!")
    print("Por favor, elige uno de los siguientes juegos:")
    print("1. Piedra, Papel, Tijeras.")
    print("2. Piedra, Papel, Tijeras, Lagarto, Spock.")
    print("3. Adivina el numero!")
    print("4. Salir")

    # Pide al usuario que seleccione un juego
    opcion = int(input("Ingresa el número del juego que deseas jugar: "))

    # Llama a la función correspondiente según la opción seleccionada
    if opcion == 1:
        print("Has elegido: Piedra, Papel, Tijeras. ¿Estás listo/a para ponerte a prueba?")
        juego1()
        
    elif opcion == 2:
        print("Has elegido: Piedra, Papel, Tijeras, Lagarto, Spock. ¿Estás listo/a para ponerte a prueba?")
        juego2()
        
    elif opcion == 3:
        print("Has elegido: Adivina el numero! ¿Estás listo/a para ponerte a prueba?")  
        juego3()
        
    elif opcion== 4:
        print("Has dejado el juego")
    else:
        print("Opción inválida. Por favor, selecciona un número del 1 al 3.")
    print("¡Gracias por jugar! ¡Espero que hayas pasado un buen rato!")

# %% [markdown]
# Mejoras:
#
# -En juego1():
# solo añadí una descripción de la función y su comportamiento.
# En la segunda función juego1, realicé los siguientes cambios:
# Cambié el mensaje de bienvenida para que sea más claro que el usuario debe ingresar su nombre.
# Agregué un ciclo while para verificar que el nombre del usuario no sea una cadena vacía.
# Agregué una pregunta al usuario si desea jugar de nuevo y agregué un ciclo while para verificar que el usuario ingrese una respuesta válida.
# Removí la cadena de formato del mensaje de victorias del programa y lo concatené directamente con el valor de la variable puntuacion_programa para ser más eficiente.
#
# -En juego2():
#
# En la función determinar_ganador, agregué comentarios que explican el funcionamiento del código.
#
# En la función jugar, agregué un mensaje que indica cuántas rondas se jugarán.
#
# En la función jugar, agregué un contador de rondas para que se muestre en qué ronda se encuentra el juego.
#
# En la función jugar, agregué un mensaje que indica cuántas victorias necesita un jugador para ganar el juego.
#
# En la función jugar, agregué un contador de victorias para cada jugador y un mensaje que indica cuántas victorias tiene cada jugador después de cada ronda.
#
# En la función jugar, agregué un mensaje que indica quién ganó el juego al finalizar todas las rondas.
#
# En la función jugar, agregué un mensaje que indica si el usuario o el programa ganó la ronda. Además, agregué un mensaje que
# indica si el usuario o el programa ganó el juego.
#
# En la función jugar, agregué un mensaje que indica que el usuario ingresó una opción inválida si la opción ingresada no está en la lista de opciones.
#
# En la función jugar, agregué un mensaje que indica que se jugará una nueva ronda si el usuario ingresó "s" para jugar nuevamente, y agregué un mensaje de despedida si el usuario ingresó "n".
#
# -En juego3():
# ad

# %%
import random


def determinar_ganador1(opcion_usuario: str, opcion_programa: str) -> str:
    """
    Determina el ganador de una ronda del juego de piedra, papel o tijera.

    Args:
        opcion_usuario (str): La opción elegida por el usuario.
        opcion_programa (str): La opción elegida por el programa.

    Returns:
        str: El ganador de la ronda: "usuario", "programa" o "empate".
    """    
    # Compara la opción del usuario con la del programa para determinar el ganador
    reglas = {
        "piedra": ["tijera"],
        "papel": ["piedra"],
        "tijera": ["papel"]
    }
    if opcion_usuario == opcion_programa:
        return "empate"
    elif opcion_programa in reglas[opcion_usuario]:
        return "usuario"
    else:
        return "programa"

def juego1() -> None:
    """
    Función principal del juego de piedra, papel o tijera.
    Permite al usuario jugar varias rondas contra el programa.
    """
    # Función principal del juego de piedra, papel o tijera.
    # Permite al usuario jugar varias rondas contra el programa.
    opciones = ["piedra", "papel", "tijera"]
    victorias_usuario = 0
    victorias_programa = 0
    
    nombre_usuario = input("Ingresa tu nombre: ")
    while nombre_usuario == "":
        nombre_usuario = input("Ingresa un nombre válido: ")
    
    while True:
        opcion_usuario = input("Ingresa tu opción (piedra, papel o tijera): ").lower()
        while opcion_usuario not in opciones:
            opcion_usuario = input("Opción inválida. Ingresa tu opción (piedra, papel o tijera): ").lower()
        
        opcion_programa = random.choice(opciones)
        
        print(f"{nombre_usuario}, elegiste {opcion_usuario}, el programa eligió {opcion_programa}")
        ganador_ronda = determinar_ganador1(opcion_usuario, opcion_programa)
        if ganador_ronda == "empate":
            print("\n\t Empate\n")
        elif ganador_ronda == "usuario":
            print("\n\t Ganaste\n")
            victorias_usuario += 1
        else:
            print("\n\t Perdiste\n")
            victorias_programa += 1
        
        print("Victorias de", nombre_usuario + ":", victorias_usuario)
        print("Victorias del programa:", victorias_programa)
        
        jugar_nuevamente = input("¿Quieres jugar de nuevo? (s/n): ")
        while jugar_nuevamente.lower() != "s" and jugar_nuevamente.lower() != "n":
            jugar_nuevamente = input("Respuesta inválida. ¿Quieres jugar de nuevo? (s/n): ")
        if jugar_nuevamente.lower() != "s":
            print("¡Gracias por jugar!")
            break
            
def mostrar_reglas2() -> None:
    """
    Muestra las reglas del juego.
    """
    print("Bienvenido al juego de piedra, papel, tijera, lagarto, spock.")
    print("Las reglas del juego son las siguientes:")
    print("- Piedra aplasta tijera y lagarto.")
    print("- Papel cubre piedra y desautoriza spock.")
    print("- Tijera corta papel y decapita lagarto.")
    print("- Lagarto envenena a spock y se come el papel.")
    print("- Spock destruye tijera y vaporiza piedra.")
    

def determinar_ganador2(opcion_usuario: str, opcion_programa: str) -> str:
    """
    Determina el ganador de una ronda del juego de piedra, papel, tijera, lagarto, spock.

    Args:
        opcion_usuario (str): La opción elegida por el usuario.
        opcion_programa (str): La opción elegida por el programa.

    Returns:
        str: El ganador de la ronda: "usuario", "programa" o "empate".
    """
    reglas = {
        "piedra": ["tijera", "lagarto"],
        "papel": ["piedra", "spock"],
        "tijera": ["papel", "lagarto"],
        "lagarto": ["papel", "spock"],
        "spock": ["piedra", "tijera"]
    }
    if opcion_usuario == opcion_programa:
        return "empate"
    elif opcion_programa in reglas[opcion_usuario]:
        return "usuario"
    else:
        return "programa"
    
    
def juego2() -> None:
    """
    Función principal del juego de piedra, papel, tijera, lagarto, spock.
    Permite al usuario jugar varias rondas contra el programa.
    """
    opciones = ["piedra", "papel", "tijera", "lagarto", "spock"]
    victorias_usuario = 0
    victorias_programa = 0
    nombre_usuario = input("Ingresa tu nombre: ")
    num_rondas = int(input("Ingresa el número de rondas que quieres jugar: "))
    
    for i in range(num_rondas):
        print(f"\nRonda {i+1}")
        opcion_usuario = input("Ingresa tu opción (piedra, papel, tijera, lagarto o spock): ").lower()
        while opcion_usuario not in opciones:
            opcion_usuario = input("Opción inválida. Ingresa tu opción (piedra, papel, tijera, lagarto o spock): ").lower()
        
        opcion_programa = random.choice(opciones)
        
        print(f"Tú elegiste {opcion_usuario}, el programa eligió {opcion_programa}")
        ganador_ronda = determinar_ganador2(opcion_usuario, opcion_programa)
        if ganador_ronda == "empate":
            print("\n\t Empate\n")
        elif ganador_ronda == "usuario":
            print("\n\t Ganaste\n")
            victorias_usuario += 1
        else:
            print("\n\t Perdiste\n")
            victorias_programa += 1
        
        print(f"Victorias de {nombre_usuario}: {victorias_usuario}")
        print(f"Victorias del programa: {victorias_programa}")
        
        if i < num_rondas - 1:
            jugar_nuevamente = input("Presiona enter para continuar a la siguiente ronda.")
        else:
            if victorias_usuario > victorias_programa:
                print(f"\nFelicidades, {nombre_usuario}, ganaste el juego!")
            elif victorias_usuario < victorias_programa:
                print(f"\nLo siento, {nombre_usuario}, perdiste el juego.")
            else:
                print(f"\nEl juego terminó en empate.")
            break
            

def juego3():
    """
    This function allows the player to guess a random number between 1 and 10.
    The player has 5 attempts to guess the number correctly.
    If the player fails to guess the number in 5 attempts, they lose the game.
    The player can choose to play again or quit after each game.
    """
    while True: 
        secret_number = random.randint(1, 10)
        guess = None
        num_tries = 0
    
        while guess != secret_number:
            guess = int(input("Guess a number from 1 to 10: "))
            num_tries += 1
         
            if guess < secret_number:
                print("\n\t FAIL\n")
                print("Too low, try again!")
              
            elif guess > secret_number:
                print("\n\t FAIL\n")
                print("Too high, try again!")
           
            else:
                print(f"Congratulations! {guess} is correct!")
                print(f"You took {num_tries} tries.")
        
            if num_tries == 5:
                print("\nWARNING: You have used 5 attempts.")
                print("If you fail to guess the number on the next try, you lose the game.")
        
        if num_tries >= 5:
            print("\nYou've had 5 attempts or more. Think more carefully!")
        
        jugar_nuevamente = input("¿Want to play again? (y/n): ")
        if jugar_nuevamente.lower() != "y":
            break  
                
    print("End of the game")
    
def Jugar():
    """
    Función principal del proyecto.
    Permite al usuario jugar i seleccionar  el juego a jugar contra el programa.
    """
    print("¡Bienvenido a la sala de juegos!")
    print("Por favor, elige uno de los siguientes juegos:")
    print("1. Piedra, Papel, Tijeras.")
    print("2. Piedra, Papel, Tijeras, Lagarto, Spock.")
    print("3. Adivina el numero!")
    print("4. Reglas del ""Piedra, Papel, Tijeras, Lagarto, Spock, """)
    print("5. Salir.")

    # Pide al usuario que seleccione un juego
    opcion = int(input("Ingresa el número del juego que deseas jugar: "))

    # Llama a la función correspondiente según la opción seleccionada
    if opcion == 1:
        print("Has elegido: Piedra, Papel, Tijeras. ¿Estás listo/a para ponerte a prueba?")
        juego1()
        print("¡Gracias por jugar! ¡Espero que hayas pasado un buen rato!")
        input("Presiona enter para volver a la pantalla de inicio.")
        Jugar()
    elif opcion == 2:
        print("Has elegido: Piedra, Papel, Tijeras, Lagarto, Spock. ¿Estás listo/a para ponerte a prueba?")
        juego2()
        print("¡Gracias por jugar! ¡Espero que hayas pasado un buen rato!")
        input("Presiona enter para volver a la pantalla de inicio.")
        Jugar()
    elif opcion == 3:
        print("Has elegido: Adivina el numero! ¿Estás listo/a para ponerte a prueba?")  
        juego3()
        print("¡Gracias por jugar! ¡Espero que hayas pasado un buen rato!")
        input("Presiona enter para volver a la pantalla de inicio.")
        Jugar()
    elif opcion== 4:
        mostrar_reglas2()
        input("Presiona enter para volver a la pantalla de inicio.")
        Jugar()
    elif opcion== 5:    
        print("¡Hasta la próxima! ")
    else:
        print("Opción inválida. Por favor, selecciona un número del 1 al 3.")

# %%
def show_rules2() -> None:
    """
    Shows the rules of the game.
    """
    print("Welcome to the Rules of Games room!")
    print("Please choose one of the following games rules:")
    print("1. Rock, Paper, Scissors.")
    print("2. Rock, Paper, Scissors, Lizard, Spock.")
    print("3. Guess the number!")
    print("4. Exit.")
    
    while True:
        option = input("Enter the number of the game you want to check the rules: ")
        if option == '':
            print("Invalid input. Please enter a number from 1 to 4.")
        elif option.isdigit():
            option = int(option)
            if option < 1 or option > 5:
                print("Invalid input. Please enter a number from 1 to 4.")
            else:
                break
        else:
            print("Invalid input. Please enter a number from 1 to 4.")

    if option == 1:
        print("You have chosen: Rock, Paper, Scissors. The rules are:)
        print("The rules of the game are as follows:")
        print("- Rock crushes scissors.")
        print("- Paper covers rock.")
        print("- Scissors cuts paper.")        
        input("Press enter to go back to the main menu.")
        show_rules2()
    elif option == 2:
        print("You have chosen: Rock, Paper, Scissors, Lizard, Spock. The rules are:")
        print("The rules of the game are as follows:")
        print("- Rock crushes scissors and lizard.")
        print("- Paper covers rock and disproves spock.")
        print("- Scissors cuts paper and decapitates lizard.")
        print("- Lizard poisons spock and eats paper.")
        print("- Spock smashes scissors and vaporizes rock.")        
        print("Thanks for playing! I hope you had a good time!")
        input("Press enter to go back to the main menu.")
        show_rules2()
    elif option == 3:
        print("You have chosen: Guess the number! The rules are:")
        print("You have to guess a number from 1 to 10. The program will encorauge you to take only 5 tries to guess.")
        print("You can still guess after 5 tries.")
        input("Press enter to go back to the main menu.")
        show_rules2()
    elif option == 4:
        print("Until next time! ")
       
    else:
        print("Invalid option. Please select a number from 1 to 4.")

# %%
def show_rules2() -> None:
    """
    Shows the rules of the game.
    """
    print("Welcome to the game of rock, paper, scissors, lizard, spock.")
    print("The rules of the game are as follows:")
    print("- Rock crushes scissors and lizard.")
    print("- Paper covers rock and disproves spock.")
    print("- Scissors cuts paper and decapitates lizard.")
    print("- Lizard poisons spock and eats paper.")
    print("- Spock smashes scissors and vaporizes rock.")
# Define una funcion que enseñara un menu teh opciones para leer las reglas de los 3 juegos.

# %%
def show_rules2() -> None:
    """
    Shows the rules of the game.
    """
    # Welcome the user to the Rules of Games room.
    print("Welcome to the Rules of Games room!")
    # Show the available games and their corresponding numbers.
    print("Please choose one of the following games rules:")
    print("1. Rock, Paper, Scissors.")
    print("2. Rock, Paper, Scissors, Lizard, Spock.")
    print("3. Guess the number!")
    print("4. Exit.")
    
    # Keep asking the user for an option until they enter a valid one.
    while True:
        option = input("Enter the number of the game you want to check the rules: ")
        if option == '':
            print("Invalid input. Please enter a number from 1 to 4.")
        elif option.isdigit():
            option = int(option)
            if option < 1 or option > 4:
                print("Invalid input. Please enter a number from 1 to 4.")
            else:
                break
        else:
            print("Invalid input. Please enter a number from 1 to 4.")

    # Show the rules of the selected game and prompt the user to go back to the main menu.
    if option == 1:
        print("You have chosen: Rock, Paper, Scissors. The rules are:")
        print("The rules of the game are as follows:")
        print("- Rock crushes scissors.")
        print("- Paper covers rock.")
        print("- Scissors cuts paper.")        
        input("Press enter to go back to the main menu.")
        show_rules2()
    elif option == 2:
        print("You have chosen: Rock, Paper, Scissors, Lizard, Spock. The rules are:")
        print("The rules of the game are as follows:")
        print("- Rock crushes scissors and lizard.")
        print("- Paper covers rock and disproves spock.")
        print("- Scissors cuts paper and decapitates lizard.")
        print("- Lizard poisons spock and eats paper.")
        print("- Spock smashes scissors and vaporizes rock.")        
        input("Press enter to go back to the main menu.")
        show_rules2()
    elif option == 3:
        print("You have chosen: Guess the number! The rules are:")
        print("You have to guess a number from 1 to 10. The program will encourage you to take only 5 tries to guess.")
        print("You can still guess after 5 tries.")
        input("Press enter to go back to the main menu.")
        show_rules2()
    elif option == 4:
        print("Until next time! ")
       
    else:
        print("Invalid option. Please select a number from 1 to 4.")
